# %%
from modules import solve_2D_schrodinger as s2ds
import numpy as np
# %pylab notebook
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %%time
s=s2ds.setup_2d_schrodinger(N=40,pad=0.05,V0=1e5)
s.get_potential("SW")
s.get_eigen()
# Out:
# CPU times: user 17.9 s, sys: 200 ms, total: 18.1 s
# Wall time: 13.8 s

# %%
# %%time
sn=s2ds.setup_2d_schrodinger(N=40,pad=0.05,V0=1e5,newd2=True)
sn.get_potential("SW")
sn.get_eigen()
# Out:
# CPU times: user 5.44 s, sys: 87.4 ms, total: 5.53 s
# Wall time: 735 ms

# %%
# %%time
sn4=s2ds.setup_2d_schrodinger(N=40,pad=0.05,V0=1e5,newd2=True,coeff={-2.:-1/12.,-1.:4./3.,0:-5./2.,1.:4./3.,2.:-1./12.})
sn4.get_potential("SW")
sn4.get_eigen()
# Out:
# CPU times: user 5.54 s, sys: 60.9 ms, total: 5.6 s
# Wall time: 758 ms

# %%
coeff={-3.:1./90.,-2.:-3./20.,-1.:3./2.,0:-49./18.,1.:3./2.,2.:-3./20,3.:1./90.}
sn6=s2ds.setup_2d_schrodinger(N=40,pad=0.05,V0=1e5,newd2=True,coeff=coeff)
sn6.get_potential("SW")
sn6.get_eigen()

# %%
coeff={-4.:-1./560.,-3.:8./315.,-2.:-1./5.,-1.:8./5.,0.:-205./72.,1.:8./5.,2.:-1./5.,3:8./315.,4.:-1./560.}
sn8=s2ds.setup_2d_schrodinger(N=40,pad=0.05,V0=1e5,newd2=True,coeff=coeff)
sn8.get_potential("SW")
sn8.get_eigen()

# %%
figure()
plot((sn8.En+sn8.V0)/(sn6.En+sn6.V0))
plot((sn8.En+sn8.V0)/(sn4.En+sn4.V0),"c-")
plot((sn8.En+sn8.V0)/(sn.En+sn.V0),"k-")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
L=2-4.*sn4.pad
nx=1. ; ny=1.
Ethry=[]
for nx in range(20):
    for ny in range(20):
        Ethry=Ethry + [pi**2*((nx+1)**2+(ny+1)**2.)/L**2.]
        
figure()
plot(sn4.En+sn4.V0)
plot(sn.En+sn.V0,"r-")
plot(np.sort(Ethry),"k-")
loglog()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# []

# %%
En={}
Nary=[40,60,80]#,100,120]
for i,N in enumerate(Nary):
    print(N)
    snew=s2ds.setup_2d_schrodinger(N=N,pad=0.1,V0=1e9,newd2=True,coeff=coeff)
    snew.get_potential("SW")
    snew.get_eigen()
    En[N]=(snew.En+snew.V0)
# Out:
# 40
# 60
# 80

# %%
L=2-4.*snew.pad
Ethry=[]
for nx in range(120):
    for ny in range(120):
        Ethry=Ethry + [pi**2*((nx+1)**2+(ny+1)**2.)/L**2.]
Ethry=np.sort(Ethry)

# %%
# Ethry=np.sort(Ethry)
# Ethry=np.unique(Ethry)
# len(Ethry)

# %%
figure()
plot(En[80])
plot(Ethry)
xlim(0,15000)
ylim(0,25000)
# loglog()

figure()
plot((En[80][:4000]-Ethry[:4000])/Ethry[:4000])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
En[120][:20]
# Out:
# array([ 5.90388191, 14.75969982, 14.7597003 , 23.61551857, 29.51938236,
#        29.5193826 , 38.37520099, 38.37520099, 50.18290615, 50.18290615,
#        53.13488305, 59.03872406, 59.03872442, 73.7984066 , 73.79840708,
#        76.75023878, 76.75023901, 85.60605693, 85.60605693, 94.46193039])

# %%
Ethry[:20]
# Out:
# array([ 6.0923484 , 15.23087099, 15.23087099, 24.36939358, 30.46174198,
#        30.46174198, 39.60026457, 39.60026457, 51.78496136, 51.78496136,
#        54.83113556, 60.92348396, 60.92348396, 76.15435495, 76.15435495,
#        79.20052914, 79.20052914, 88.33905174, 88.33905174, 97.47757433])

# %%
imax=3000
figure()
plot(En[60][:imax]/Ethry[:imax])
plot(En[80][:imax]/Ethry[:imax],"k-")
plot(En[120][:imax]/Ethry[:imax],"m-")
# plot(En[40][:imax]/Ethry[:imax],"g-")
ylim(0.8,1)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (0.8, 1.0)

# %%
figure()
plot(En[40])
plot(En[60])
plot(En[80])
plot(En[120])

plot(Ethry,"k-")
ylim(0,15000)
xlim(0,2000)
# loglog()

figure()
plot(np.unique(np.round(En[40][:400],5))[:53])
plot(np.unique(np.round(En[60][:400],5))[:53])

plot(np.unique(np.round(En[80][:400],5))[:53],"k--")
plot(np.unique(Ethry)[:53],"m-")
# loglog()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
figure()
plot(np.unique(np.round(En[40][:400],4))[:52]/np.unique(Ethry)[:52])
plot(np.unique(np.round(En[60][:400],4))[:52]/np.unique(Ethry)[:52])
plot(np.unique(np.round(En[80][:400],4))[:52]/np.unique(Ethry)[:52],"k--")
# plot(Ethry/Ethry)
plot(np.unique(np.round(En[120][:400],4))[:52]/np.unique(Ethry)[:52],"k--")
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
O=-snew.O + np.diag(snew.V)

# %%
np.diag(O,snew.N+2)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])

# %%
aband=np.zeros((snew.N,snew.N**2),float)
for i in range(snew.N):
    aband[i,i:]=np.diag(O,i)

# %%
import scipy
En,Ev=scipy.linalg.eig_banded(aband)

# %%
figure()
imshow(Ev[:,1000].reshape(snew.N,snew.N))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
h=6.626e-34
hbar=h/2/pi
ech=1.60217662e-19
csol=299792458.
# Out:
# 1000000000.0
